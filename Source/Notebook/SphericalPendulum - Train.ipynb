# %%
import numpy as np
import sys 
sys.path.append(r'../Python Script/')

from sympy import symbols, simplify, derive_by_array
from scipy.integrate import solve_ivp
from xLSINDy import *
from sympy.physics.mechanics import *
from sympy import *
import sympy

import torch
import sys 
sys.path.append(r'../../HLsearch/')
import HLsearch as HL
import matplotlib.pyplot as plt

# %%
import time

def generate_data(func, time, init_values):
    sol = solve_ivp(func,[time[0],time[-1]],init_values,t_eval=time, method='RK45',rtol=1e-10,atol=1e-10)
    return sol.y.T, np.array([func(0,sol.y.T[i,:]) for i in range(sol.y.T.shape[0])],dtype=np.float64)

g = 9.81
m = 1
l = 1

def spherePend(t,y,Moment=0.0):
    from numpy import sin, cos
    theta, psi, theta_t, psi_t = y
    theta_2t = sin(theta)*cos(theta)*psi_t**2 - (g/l)*sin(theta)
    psi_2t = -2*theta_t*psi_t*cos(theta)/sin(theta)
    return theta_t,psi_t,theta_2t,psi_2t

# %%
#Saving Directory
rootdir = "../Spherical Pendulum/Data/"

num_sample = 100
create_data = False
training = True
save = False
noiselevel = 0

# %%
if(create_data):
    X, Xdot = [], []
    for i in range(num_sample):
        t = np.arange(0,5,0.01)
        theta = np.random.uniform(np.pi/3, np.pi/2)
        
        y0=np.array([theta, 0, 0, np.pi])
        x,xdot = generate_data(spherePend,t,y0)
        X.append(x)
        Xdot.append(xdot)
    X = np.vstack(X)
    Xdot = np.vstack(Xdot)
    if(save==True):
        np.save(rootdir + "X.npy", X)
        np.save(rootdir + "Xdot.npy",Xdot)
else:
    X = np.load(rootdir + "X.npy")
    Xdot = np.load(rootdir + "Xdot.npy")

# %%
#adding noise
mu, sigma = 0, noiselevel
noise = np.random.normal(mu, sigma, X.shape[0])
for i in range(X.shape[1]):
    X[:,i] = X[:,i]+noise
    Xdot[:,i] = Xdot[:,i]+noise

# %%
states_dim = 4
states = ()
states_dot = ()
for i in range(states_dim):
    if(i<states_dim//2):
        states = states + (symbols('x{}'.format(i)),)
        states_dot = states_dot + (symbols('x{}_t'.format(i)),)
    else:
        states = states + (symbols('x{}_t'.format(i-states_dim//2)),)
        states_dot = states_dot + (symbols('x{}_tt'.format(i-states_dim//2)),)
print('states are:',states)
print('states derivatives are: ', states_dot)

#Turn from sympy to str
states_sym = states
states_dot_sym = states_dot
states = list(str(descr) for descr in states)
states_dot = list(str(descr) for descr in states_dot)
# Out:
# states are: (x0, x1, x0_t, x1_t)
# states derivatives are:  (x0_t, x1_t, x0_tt, x1_tt)

# %%
#build function expression for the library in str
exprdummy = HL.buildFunctionExpressions(1,states_dim,states,use_sine=True)
polynom = exprdummy[1:4]
trig = [exprdummy[4], exprdummy[6]]
polynom = HL.buildFunctionExpressions(2,len(polynom),polynom)
trig = HL.buildFunctionExpressions(2, len(trig),trig)
product = []
for p in polynom:
    for t in trig:
        product.append(p + '*' + t)
expr = polynom + trig + product

# %%
#Creating library tensor
Zeta, Eta, Delta = LagrangianLibraryTensor(X,Xdot,expr,states,states_dot, scaling=False)

# %%
## separating known and unknown terms ##
expr = np.array(expr)
i1 = np.where(expr == 'x0_t**2')[0]
i2 = np.where(expr == 'x0_t**2*cos(x0)**2')[0]

idx = np.arange(0,len(expr))
idx = np.delete(idx,[i1,i2])
known_expr = expr[i1].tolist()
expr = np.delete(expr,[i1,i2])

#non-penalty index from prev knowledge
i3 = np.where(expr == 'cos(x0)')[0][0]
nonpenaltyidx=[i3]

expr = expr.tolist()

Zeta_ = Zeta[:,:,i1,:].clone().detach()
Eta_ = Eta[:,:,i1,:].clone().detach()
Delta_ = Delta[:,i1,:].clone().detach()

Zeta = Zeta[:,:,idx,:]
Eta = Eta[:,:,idx,:]
Delta = Delta[:,idx,:]

# %%
#Moving to Cuda
device = 'cuda:0'

Zeta = Zeta.to(device)
Eta = Eta.to(device)
Delta = Delta.to(device)

Zeta_ = Zeta_.to(device)
Eta_ = Eta_.to(device)
Delta_ = Delta_.to(device)

# %%
xi_L = torch.ones(len(expr), device=device).data.uniform_(-20,20)
prevxi_L = xi_L.clone().detach()
c = torch.ones(len(known_expr), device=device, requires_grad =False)

# %%
def loss(pred, targ):
    loss = torch.mean((pred - targ)**2) 
    return loss

# %%
def clip(w, alpha):
    clipped = torch.minimum(w,alpha)
    clipped = torch.maximum(clipped,-alpha)
    return clipped

def proxL1norm(w_hat, alpha, nonpenaltyidx):
    if(torch.is_tensor(alpha)==False):
        alpha = torch.tensor(alpha)
    w = w_hat - clip(w_hat,alpha)
    for idx in nonpenaltyidx:
        w[idx] = w_hat[idx]
    return w

# %%
def training_loop(c, coef, prevcoef, RHS, LHS, xdot, bs, lr, lam, momentum=True):
    loss_list = []
    tl = xdot.shape[0]
    n = xdot.shape[1]

    Zeta_, Eta_, Delta_ = LHS 
    Zeta, Eta, Delta = RHS

    if(torch.is_tensor(xdot)==False):
        xdot = torch.from_numpy(xdot).to(device).float()
    
    v = coef.clone().detach().requires_grad_(True)
    prev = v
    
    for i in range(tl//bs):
                
        #computing acceleration with momentum
        if(momentum==True):
            vhat = (v + ((i-1)/(i+2))*(v - prev)).clone().detach().requires_grad_(True)
        else:
            vhat = v.requires_grad_(True).clone().detach().requires_grad_(True)
   
        prev = v

        #Computing loss
        zeta = Zeta[:,:,:,i*bs:(i+1)*bs]
        eta = Eta[:,:,:,i*bs:(i+1)*bs]
        delta = Delta[:,:,i*bs:(i+1)*bs]

        zeta_ = Zeta_[:,:,:,i*bs:(i+1)*bs]
        eta_ = Eta_[:,:,:,i*bs:(i+1)*bs]
        delta_ = Delta_[:,:,i*bs:(i+1)*bs]
        
        x_t = xdot[i*bs:(i+1)*bs,:]

        #forward
        pred = -ELforward(vhat,zeta,eta,delta,x_t,device)
        targ = ELforward(c,zeta_,eta_,delta_,x_t,device)
        #targ = torque[:,i*bs:(i+1)*bs]
        
        lossval = loss(pred, targ)
        
        #Backpropagation
        lossval.backward()

        with torch.no_grad():
            v = vhat - lr*vhat.grad
            v = (proxL1norm(v,lr*lam,nonpenaltyidx))
            
            # Manually zero the gradients after updating weights
            vhat.grad = None
        
        
    
        
        loss_list.append(lossval.item())
    print("Average loss : " , torch.tensor(loss_list).mean().item())
    return v, prevcoef, torch.tensor(loss_list).mean().item()

# %%
Epoch = 100
i = 0
lr = 5e-6
lam = 5
temp = 1000
RHS = [Zeta, Eta, Delta]
LHS = [Zeta_, Eta_, Delta_]
while(i<=Epoch):
    print("\n")
    print("Stage 1")
    print("Epoch "+str(i) + "/" + str(Epoch))
    print("Learning rate : ", lr)
    xi_L, prevxi_L, lossitem= training_loop(c,xi_L,prevxi_L,RHS,LHS,Xdot,128,lr=lr,lam=lam)
    temp = lossitem
    i+=1
# Out:
# Stage 1
# Epoch 0/100
# Learning rate :  5e-06
# Average loss :  76530.953125
#
#
# Stage 1
# Epoch 1/100
# Learning rate :  5e-06
# Average loss :  2939.46484375
#
#
# Stage 1
# Epoch 2/100
# Learning rate :  5e-06
# Average loss :  865.51513671875
#
#
# Stage 1
# Epoch 3/100
# Learning rate :  5e-06
# Average loss :  393.398681640625
#
#
# Stage 1
# Epoch 4/100
# Learning rate :  5e-06
# Average loss :  164.3717041015625
#
#
# Stage 1
# Epoch 5/100
# Learning rate :  5e-06
# Average loss :  94.33831024169922
#
#
# Stage 1
# Epoch 6/100
# Learning rate :  5e-06
# Average loss :  68.93724822998047
#
#
# Stage 1
# Epoch 7/100
# Learning rate :  5e-06
# Average loss :  60.98732376098633
#
#
# Stage 1
# Epoch 8/100
# Learning rate :  5e-06
# Average loss :  55.10904312133789
#
#
# Stage 1
# Epoch 9/100
# Learning rate :  5e-06
# Average loss :  49.97760009765625
#
#
# Stage 1
# Epoch 10/100
# Learning rate :  5e-06
# Average loss :  46.42514419555664
#
#
# Stage 1
# Epoch 11/100
# Learning rate :  5e-06
# Average loss :  42.0601806640625
#
#
# Stage 1
# Epoch 12/100
# Learning rate :  5e-06
# Average loss :  36.051387786865234
#
#
# Stage 1
# Epoch 13/100
# Learning rate :  5e-06
# Average loss :  31.533845901489258
#
#
# Stage 1
# Epoch 14/100
# Learning rate :  5e-06
# Average loss :  27.904035568237305
#
#
# Stage 1
# Epoch 15/100
# Learning rate :  5e-06
# Average loss :  26.19055938720703
#
#
# Stage 1
# Epoch 16/100
# Learning rate :  5e-06
# Average loss :  25.610464096069336
#
#
# Stage 1
# Epoch 17/100
# Learning rate :  5e-06
# Average loss :  22.764606475830078
#
#
# Stage 1
# Epoch 18/100
# Learning rate :  5e-06
# Average loss :  19.301555633544922
#
#
# Stage 1
# Epoch 19/100
# Learning rate :  5e-06
# Average loss :  15.56085205078125
#
#
# Stage 1
# Epoch 20/100
# Learning rate :  5e-06
# Average loss :  13.248680114746094
#
#
# Stage 1
# Epoch 21/100
# Learning rate :  5e-06
# Average loss :  9.946478843688965
#
#
# Stage 1
# Epoch 22/100
# Learning rate :  5e-06
# Average loss :  7.361907005310059
#
#
# Stage 1
# Epoch 23/100
# Learning rate :  5e-06
# Average loss :  5.702010154724121
#
#
# Stage 1
# Epoch 24/100
# Learning rate :  5e-06
# Average loss :  4.3849639892578125
#
#
# Stage 1
# Epoch 25/100
# Learning rate :  5e-06
# Average loss :  3.6010918617248535
#
#
# Stage 1
# Epoch 26/100
# Learning rate :  5e-06
# Average loss :  2.7623982429504395
#
#
# Stage 1
# Epoch 27/100
# Learning rate :  5e-06
# Average loss :  2.6319196224212646
#
#
# Stage 1
# Epoch 28/100
# Learning rate :  5e-06
# Average loss :  2.11704421043396
#
#
# Stage 1
# Epoch 29/100
# Learning rate :  5e-06
# Average loss :  1.1926344633102417
#
#
# Stage 1
# Epoch 30/100
# Learning rate :  5e-06
# Average loss :  0.6139587163925171
#
#
# Stage 1
# Epoch 31/100
# Learning rate :  5e-06
# Average loss :  0.31043484807014465
#
#
# Stage 1
# Epoch 32/100
# Learning rate :  5e-06
# Average loss :  0.170583114027977
#
#
# Stage 1
# Epoch 33/100
# Learning rate :  5e-06
# Average loss :  0.13227270543575287
#
#
# Stage 1
# Epoch 34/100
# Learning rate :  5e-06
# Average loss :  0.09825824946165085
#
#
# Stage 1
# Epoch 35/100
# Learning rate :  5e-06
# Average loss :  0.08945934474468231
#
#
# Stage 1
# Epoch 36/100
# Learning rate :  5e-06
# Average loss :  0.09072936326265335
#
#
# Stage 1
# Epoch 37/100
# Learning rate :  5e-06
# Average loss :  0.09244093298912048
#
#
# Stage 1
# Epoch 38/100
# Learning rate :  5e-06
# Average loss :  0.08959651738405228
#
#
# Stage 1
# Epoch 39/100
# Learning rate :  5e-06
# Average loss :  0.08786768466234207
#
#
# Stage 1
# Epoch 40/100
# Learning rate :  5e-06
# Average loss :  0.0928625538945198
#
#
# Stage 1
# Epoch 41/100
# Learning rate :  5e-06
# Average loss :  0.09537047147750854
#
#
# Stage 1
# Epoch 42/100
# Learning rate :  5e-06
# Average loss :  0.09059759229421616
#
#
# Stage 1
# Epoch 43/100
# Learning rate :  5e-06
# Average loss :  0.09929844737052917
#
#
# Stage 1
# Epoch 44/100
# Learning rate :  5e-06
# Average loss :  0.0944274514913559
#
#
# Stage 1
# Epoch 45/100
# Learning rate :  5e-06
# Average loss :  0.09629028290510178
#
#
# Stage 1
# Epoch 46/100
# Learning rate :  5e-06
# Average loss :  0.09417711943387985
#
#
# Stage 1
# Epoch 47/100
# Learning rate :  5e-06
# Average loss :  0.096922367811203
#
#
# Stage 1
# Epoch 48/100
# Learning rate :  5e-06
# Average loss :  0.09678411483764648
#
#
# Stage 1
# Epoch 49/100
# Learning rate :  5e-06
# Average loss :  0.09883593022823334
#
#
# Stage 1
# Epoch 50/100
# Learning rate :  5e-06
# Average loss :  0.10154939442873001
#
#
# Stage 1
# Epoch 51/100
# Learning rate :  5e-06
# Average loss :  0.10181446373462677
#
#
# Stage 1
# Epoch 52/100
# Learning rate :  5e-06
# Average loss :  0.09840042889118195
#
#
# Stage 1
# Epoch 53/100
# Learning rate :  5e-06
# Average loss :  0.09345188736915588
#
#
# Stage 1
# Epoch 54/100
# Learning rate :  5e-06
# Average loss :  0.10303881764411926
#
#
# Stage 1
# Epoch 55/100
# Learning rate :  5e-06
# Average loss :  0.1000952199101448
#
#
# Stage 1
# Epoch 56/100
# Learning rate :  5e-06
# Average loss :  0.10268045961856842
#
#
# Stage 1
# Epoch 57/100
# Learning rate :  5e-06
# Average loss :  0.09683298319578171
#
#
# Stage 1
# Epoch 58/100
# Learning rate :  5e-06
# Average loss :  0.09627002477645874
#
#
# Stage 1
# Epoch 59/100
# Learning rate :  5e-06
# Average loss :  0.09992373734712601
#
#
# Stage 1
# Epoch 60/100
# Learning rate :  5e-06
# Average loss :  0.10723225772380829
#
#
# Stage 1
# Epoch 61/100
# Learning rate :  5e-06
# Average loss :  0.1012030765414238
#
#
# Stage 1
# Epoch 62/100
# Learning rate :  5e-06
# Average loss :  0.09981045126914978
#
#
# Stage 1
# Epoch 63/100
# Learning rate :  5e-06
# Average loss :  0.1052250787615776
#
#
# Stage 1
# Epoch 64/100
# Learning rate :  5e-06
# Average loss :  0.10375586152076721
#
#
# Stage 1
# Epoch 65/100
# Learning rate :  5e-06
# Average loss :  0.10322118550539017
#
#
# Stage 1
# Epoch 66/100
# Learning rate :  5e-06
# Average loss :  0.10588964074850082
#
#
# Stage 1
# Epoch 67/100
# Learning rate :  5e-06
# Average loss :  0.09659281373023987
#
#
# Stage 1
# Epoch 68/100
# Learning rate :  5e-06
# Average loss :  0.09596604853868484
#
#
# Stage 1
# Epoch 69/100
# Learning rate :  5e-06
# Average loss :  0.10650221258401871
#
#
# Stage 1
# Epoch 70/100
# Learning rate :  5e-06
# Average loss :  0.10525378584861755
#
#
# Stage 1
# Epoch 71/100
# Learning rate :  5e-06
# Average loss :  0.1133088693022728
#
#
# Stage 1
# Epoch 72/100
# Learning rate :  5e-06
# Average loss :  0.10561905801296234
#
#
# Stage 1
# Epoch 73/100
# Learning rate :  5e-06
# Average loss :  0.10087431967258453
#
#
# Stage 1
# Epoch 74/100
# Learning rate :  5e-06
# Average loss :  0.10949809849262238
#
#
# Stage 1
# Epoch 75/100
# Learning rate :  5e-06
# Average loss :  0.10641416907310486
#
#
# Stage 1
# Epoch 76/100
# Learning rate :  5e-06
# Average loss :  0.103265680372715
#
#
# Stage 1
# Epoch 77/100
# Learning rate :  5e-06
# Average loss :  0.11307206749916077
#
#
# Stage 1
# Epoch 78/100
# Learning rate :  5e-06
# Average loss :  0.1050245463848114
#
#
# Stage 1
# Epoch 79/100
# Learning rate :  5e-06
# Average loss :  0.10875455290079117
#
#
# Stage 1
# Epoch 80/100
# Learning rate :  5e-06
# Average loss :  0.11406410485506058
#
#
# Stage 1
# Epoch 81/100
# Learning rate :  5e-06
# Average loss :  0.10753418505191803
#
#
# Stage 1
# Epoch 82/100
# Learning rate :  5e-06
# Average loss :  0.10641457885503769
#
#
# Stage 1
# Epoch 83/100
# Learning rate :  5e-06
# Average loss :  0.1105915978550911
#
#
# Stage 1
# Epoch 84/100
# Learning rate :  5e-06
# Average loss :  0.10486289858818054
#
#
# Stage 1
# Epoch 85/100
# Learning rate :  5e-06
# Average loss :  0.11276845633983612
#
#
# Stage 1
# Epoch 86/100
# Learning rate :  5e-06
# Average loss :  0.10850821435451508
#
#
# Stage 1
# Epoch 87/100
# Learning rate :  5e-06
# Average loss :  0.10663029551506042
#
#
# Stage 1
# Epoch 88/100
# Learning rate :  5e-06
# Average loss :  0.11160816997289658
#
#
# Stage 1
# Epoch 89/100
# Learning rate :  5e-06
# Average loss :  0.10856419056653976
#
#
# Stage 1
# Epoch 90/100
# Learning rate :  5e-06
# Average loss :  0.10734150558710098
#
#
# Stage 1
# Epoch 91/100
# Learning rate :  5e-06
# Average loss :  0.10758856683969498
#
#
# Stage 1
# Epoch 92/100
# Learning rate :  5e-06
# Average loss :  0.10603725910186768
#
#
# Stage 1
# Epoch 93/100
# Learning rate :  5e-06
# Average loss :  0.11214300245046616
#
#
# Stage 1
# Epoch 94/100
# Learning rate :  5e-06
# Average loss :  0.1117333471775055
#
#
# Stage 1
# Epoch 95/100
# Learning rate :  5e-06
# Average loss :  0.11018596589565277
#
#
# Stage 1
# Epoch 96/100
# Learning rate :  5e-06
# Average loss :  0.10451260954141617
#
#
# Stage 1
# Epoch 97/100
# Learning rate :  5e-06
# Average loss :  0.10944439470767975
#
#
# Stage 1
# Epoch 98/100
# Learning rate :  5e-06
# Average loss :  0.1113147959113121
#
#
# Stage 1
# Epoch 99/100
# Learning rate :  5e-06
# Average loss :  0.10675426572561264
#
#
# Stage 1
# Epoch 100/100
# Learning rate :  5e-06
# Average loss :  0.11861228942871094

# %%
## Thresholding
threshold = 1e-2
surv_index = ((torch.abs(xi_L) >= threshold)).nonzero(as_tuple=True)[0].detach().cpu().numpy()
expr = np.array(expr)[surv_index].tolist()

xi_L =xi_L[surv_index].clone().detach().requires_grad_(True)
prevxi_L = xi_L.clone().detach()

## obtaining analytical model
xi_Lcpu = np.around(xi_L.detach().cpu().numpy(),decimals=2)
L = HL.generateExpression(xi_Lcpu,expr,threshold=1e-3)
print(simplify(L))
# Out:
# 0.96*x1_t**2*sin(x0)**2 + 18.93*cos(x0)

# %%
## Next round selection ##
for stage in range(3):

    #Redefine computation after thresholding
    expr.append(known_expr[0])
    Zeta, Eta, Delta = LagrangianLibraryTensor(X,Xdot,expr,states,states_dot, scaling=False)

    expr = np.array(expr)
    i1 = np.where(expr == 'x0_t**2')[0]
    idx = np.arange(0,len(expr))
    idx = np.delete(idx,i1)
    known_expr = expr[i1].tolist()
    expr = np.delete(expr,i1)

    i4 = np.where(expr == 'cos(x0)')[0][0]
    nonpenaltyidx = [i4]

    expr = expr.tolist()

    Zeta_ = Zeta[:,:,i1,:].clone().detach()
    Eta_ = Eta[:,:,i1,:].clone().detach()
    Delta_ = Delta[:,i1,:].clone().detach()

    Zeta = Zeta[:,:,idx,:]
    Eta = Eta[:,:,idx,:]
    Delta = Delta[:,idx,:]

    Zeta = Zeta.to(device)
    Eta = Eta.to(device)
    Delta = Delta.to(device)
    Zeta_ = Zeta_.to(device)
    Eta_ = Eta_.to(device)
    Delta_ = Delta_.to(device)

    Epoch = 100
    i = 0
    lr += lr
    lam = 0.5
    temp = 1000
    RHS = [Zeta, Eta, Delta]
    LHS = [Zeta_, Eta_, Delta_]
    while(i<=Epoch):
        print("\n")
        print("Stage " + str(stage+2))
        print("Epoch "+str(i) + "/" + str(Epoch))
        xi_L, prevxi_L, lossitem= training_loop(c, xi_L,prevxi_L,RHS,LHS,Xdot,128,lr=lr,lam=lam)
        temp = lossitem
        if(temp < 1e-3):
            break
        i+=1
    
    ## Thresholding
    threshold = 1e-1
    surv_index = ((torch.abs(xi_L) >= threshold)).nonzero(as_tuple=True)[0].detach().cpu().numpy()
    expr = np.array(expr)[surv_index].tolist()

    xi_L =xi_L[surv_index].clone().detach().requires_grad_(True)
    prevxi_L = xi_L.clone().detach()

    ## obtaining analytical model
    xi_Lcpu = np.around(xi_L.detach().cpu().numpy(),decimals=2)
    L = HL.generateExpression(xi_Lcpu,expr,threshold=1e-3)
    print("Result stage " + str(stage+2) + ":" , simplify(L))
# Out:
# Stage 2
# Epoch 0/100
# Average loss :  0.09015023708343506
#
#
# Stage 2
# Epoch 1/100
# Average loss :  0.07852653414011002
#
#
# Stage 2
# Epoch 2/100
# Average loss :  0.07212797552347183
#
#
# Stage 2
# Epoch 3/100
# Average loss :  0.06582719087600708
#
#
# Stage 2
# Epoch 4/100
# Average loss :  0.06072680279612541
#
#
# Stage 2
# Epoch 5/100
# Average loss :  0.05556623637676239
#
#
# Stage 2
# Epoch 6/100
# Average loss :  0.05014198645949364
#
#
# Stage 2
# Epoch 7/100
# Average loss :  0.04613960534334183
#
#
# Stage 2
# Epoch 8/100
# Average loss :  0.041373129934072495
#
#
# Stage 2
# Epoch 9/100
# Average loss :  0.037552423775196075
#
#
# Stage 2
# Epoch 10/100
# Average loss :  0.03345894068479538
#
#
# Stage 2
# Epoch 11/100
# Average loss :  0.029747478663921356
#
#
# Stage 2
# Epoch 12/100
# Average loss :  0.026519393548369408
#
#
# Stage 2
# Epoch 13/100
# Average loss :  0.02279512956738472
#
#
# Stage 2
# Epoch 14/100
# Average loss :  0.020229849964380264
#
#
# Stage 2
# Epoch 15/100
# Average loss :  0.0171426422894001
#
#
# Stage 2
# Epoch 16/100
# Average loss :  0.01488919835537672
#
#
# Stage 2
# Epoch 17/100
# Average loss :  0.012369882315397263
#
#
# Stage 2
# Epoch 18/100
# Average loss :  0.010744141414761543
#
#
# Stage 2
# Epoch 19/100
# Average loss :  0.009210096672177315
#
#
# Stage 2
# Epoch 20/100
# Average loss :  0.008623406291007996
#
#
# Stage 2
# Epoch 21/100
# Average loss :  0.0075018578208982944
#
#
# Stage 2
# Epoch 22/100
# Average loss :  0.00747459102421999
#
#
# Stage 2
# Epoch 23/100
# Average loss :  0.007481005042791367
#
#
# Stage 2
# Epoch 24/100
# Average loss :  0.007483988534659147
#
#
# Stage 2
# Epoch 25/100
# Average loss :  0.007477882783859968
#
#
# Stage 2
# Epoch 26/100
# Average loss :  0.007473370525985956
#
#
# Stage 2
# Epoch 27/100
# Average loss :  0.0074759372510015965
#
#
# Stage 2
# Epoch 28/100
# Average loss :  0.007470232434570789
#
#
# Stage 2
# Epoch 29/100
# Average loss :  0.006816321052610874
#
#
# Stage 2
# Epoch 30/100
# Average loss :  0.006386766210198402
#
#
# Stage 2
# Epoch 31/100
# Average loss :  0.006372146774083376
#
#
# Stage 2
# Epoch 32/100
# Average loss :  0.006368005182594061
#
#
# Stage 2
# Epoch 33/100
# Average loss :  0.006386780180037022
#
#
# Stage 2
# Epoch 34/100
# Average loss :  0.006392955780029297
#
#
# Stage 2
# Epoch 35/100
# Average loss :  0.006392955780029297
#
#
# Stage 2
# Epoch 36/100
# Average loss :  0.00639543728902936
#
#
# Stage 2
# Epoch 37/100
# Average loss :  0.00637342082336545
#
#
# Stage 2
# Epoch 38/100
# Average loss :  0.006388383451849222
#
#
# Stage 2
# Epoch 39/100
# Average loss :  0.006388927344232798
#
#
# Stage 2
# Epoch 40/100
# Average loss :  0.00639543728902936
#
#
# Stage 2
# Epoch 41/100
# Average loss :  0.00637342082336545
#
#
# Stage 2
# Epoch 42/100
# Average loss :  0.006388383451849222
#
#
# Stage 2
# Epoch 43/100
# Average loss :  0.006388927344232798
#
#
# Stage 2
# Epoch 44/100
# Average loss :  0.006392955780029297
#
#
# Stage 2
# Epoch 45/100
# Average loss :  0.00639543728902936
#
#
# Stage 2
# Epoch 46/100
# Average loss :  0.006378721445798874
#
#
# Stage 2
# Epoch 47/100
# Average loss :  0.006380870006978512
#
#
# Stage 2
# Epoch 48/100
# Average loss :  0.0063821133226156235
#
#
# Stage 2
# Epoch 49/100
# Average loss :  0.006384766194969416
#
#
# Stage 2
# Epoch 50/100
# Average loss :  0.006382381077855825
#
#
# Stage 2
# Epoch 51/100
# Average loss :  0.006385330110788345
#
#
# Stage 2
# Epoch 52/100
# Average loss :  0.006386196706444025
#
#
# Stage 2
# Epoch 53/100
# Average loss :  0.0063878134824335575
#
#
# Stage 2
# Epoch 54/100
# Average loss :  0.00638906704261899
#
#
# Stage 2
# Epoch 55/100
# Average loss :  0.006389064248651266
#
#
# Stage 2
# Epoch 56/100
# Average loss :  0.006383086089044809
#
#
# Stage 2
# Epoch 57/100
# Average loss :  0.006388927344232798
#
#
# Stage 2
# Epoch 58/100
# Average loss :  0.006392955780029297
#
#
# Stage 2
# Epoch 59/100
# Average loss :  0.00639543728902936
#
#
# Stage 2
# Epoch 60/100
# Average loss :  0.006378721445798874
#
#
# Stage 2
# Epoch 61/100
# Average loss :  0.006380870006978512
#
#
# Stage 2
# Epoch 62/100
# Average loss :  0.0063821133226156235
#
#
# Stage 2
# Epoch 63/100
# Average loss :  0.006384766194969416
#
#
# Stage 2
# Epoch 64/100
# Average loss :  0.006382381077855825
#
#
# Stage 2
# Epoch 65/100
# Average loss :  0.006385330110788345
#
#
# Stage 2
# Epoch 66/100
# Average loss :  0.006386196706444025
#
#
# Stage 2
# Epoch 67/100
# Average loss :  0.0063878134824335575
#
#
# Stage 2
# Epoch 68/100
# Average loss :  0.00638906704261899
#
#
# Stage 2
# Epoch 69/100
# Average loss :  0.006389064248651266
#
#
# Stage 2
# Epoch 70/100
# Average loss :  0.006383086089044809
#
#
# Stage 2
# Epoch 71/100
# Average loss :  0.006388927344232798
#
#
# Stage 2
# Epoch 72/100
# Average loss :  0.006392955780029297
#
#
# Stage 2
# Epoch 73/100
# Average loss :  0.00639543728902936
#
#
# Stage 2
# Epoch 74/100
# Average loss :  0.006378721445798874
#
#
# Stage 2
# Epoch 75/100
# Average loss :  0.006380870006978512
#
#
# Stage 2
# Epoch 76/100
# Average loss :  0.0063821133226156235
#
#
# Stage 2
# Epoch 77/100
# Average loss :  0.006384766194969416
#
#
# Stage 2
# Epoch 78/100
# Average loss :  0.006382381077855825
#
#
# Stage 2
# Epoch 79/100
# Average loss :  0.006385330110788345
#
#
# Stage 2
# Epoch 80/100
# Average loss :  0.006386196706444025
#
#
# Stage 2
# Epoch 81/100
# Average loss :  0.0063878134824335575
#
#
# Stage 2
# Epoch 82/100
# Average loss :  0.00638906704261899
#
#
# Stage 2
# Epoch 83/100
# Average loss :  0.006389064248651266
#
#
# Stage 2
# Epoch 84/100
# Average loss :  0.006383086089044809
#
#
# Stage 2
# Epoch 85/100
# Average loss :  0.006388927344232798
#
#
# Stage 2
# Epoch 86/100
# Average loss :  0.006392955780029297
#
#
# Stage 2
# Epoch 87/100
# Average loss :  0.00639543728902936
#
#
# Stage 2
# Epoch 88/100
# Average loss :  0.006378721445798874
#
#
# Stage 2
# Epoch 89/100
# Average loss :  0.006380870006978512
#
#
# Stage 2
# Epoch 90/100
# Average loss :  0.0063821133226156235
#
#
# Stage 2
# Epoch 91/100
# Average loss :  0.006384766194969416
#
#
# Stage 2
# Epoch 92/100
# Average loss :  0.006382381077855825
#
#
# Stage 2
# Epoch 93/100
# Average loss :  0.006385330110788345
#
#
# Stage 2
# Epoch 94/100
# Average loss :  0.006386196706444025
#
#
# Stage 2
# Epoch 95/100
# Average loss :  0.0063878134824335575
#
#
# Stage 2
# Epoch 96/100
# Average loss :  0.00638906704261899
#
#
# Stage 2
# Epoch 97/100
# Average loss :  0.006389064248651266
#
#
# Stage 2
# Epoch 98/100
# Average loss :  0.006383086089044809
#
#
# Stage 2
# Epoch 99/100
# Average loss :  0.006388927344232798
#
#
# Stage 2
# Epoch 100/100
# Average loss :  0.006392955780029297
#
#
# Stage 3
# Epoch 0/100
# Average loss :  0.005488083232194185
#
#
# Stage 3
# Epoch 1/100
# Average loss :  0.0041717588901519775
#
#
# Stage 3
# Epoch 2/100
# Average loss :  0.0031938247848302126
#
#
# Stage 3
# Epoch 3/100
# Average loss :  0.002506970427930355
#
#
# Stage 3
# Epoch 4/100
# Average loss :  0.0022916821762919426
#
#
# Stage 3
# Epoch 5/100
# Average loss :  0.0022900698240846395
#
#
# Stage 3
# Epoch 6/100
# Average loss :  0.0022917911410331726
#
#
# Stage 3
# Epoch 7/100
# Average loss :  0.002292298013344407
#
#
# Stage 3
# Epoch 8/100
# Average loss :  0.0022915611043572426
#
#
# Stage 3
# Epoch 9/100
# Average loss :  0.0022920190822333097
#
#
# Stage 3
# Epoch 10/100
# Average loss :  0.002292298013344407
#
#
# Stage 3
# Epoch 11/100
# Average loss :  0.0022927015088498592
#
#
# Stage 3
# Epoch 12/100
# Average loss :  0.002293315250426531
#
#
# Stage 3
# Epoch 13/100
# Average loss :  0.0022918148897588253
#
#
# Stage 3
# Epoch 14/100
# Average loss :  0.002294287085533142
#
#
# Stage 3
# Epoch 15/100
# Average loss :  0.002292011398822069
#
#
# Stage 3
# Epoch 16/100
# Average loss :  0.0022915212903171778
#
#
# Stage 3
# Epoch 17/100
# Average loss :  0.002292040968313813
#
#
# Stage 3
# Epoch 18/100
# Average loss :  0.002272853394970298
#
#
# Stage 3
# Epoch 19/100
# Average loss :  0.0017301683546975255
#
#
# Stage 3
# Epoch 20/100
# Average loss :  0.001735794241540134
#
#
# Stage 3
# Epoch 21/100
# Average loss :  0.001740448409691453
#
#
# Stage 3
# Epoch 22/100
# Average loss :  0.0017333680298179388
#
#
# Stage 3
# Epoch 23/100
# Average loss :  0.0017310112016275525
#
#
# Stage 3
# Epoch 24/100
# Average loss :  0.0017343475483357906
#
#
# Stage 3
# Epoch 25/100
# Average loss :  0.001730685238726437
#
#
# Stage 3
# Epoch 26/100
# Average loss :  0.0017361348727717996
#
#
# Stage 3
# Epoch 27/100
# Average loss :  0.001740280189551413
#
#
# Stage 3
# Epoch 28/100
# Average loss :  0.0017315908335149288
#
#
# Stage 3
# Epoch 29/100
# Average loss :  0.0017363205552101135
#
#
# Stage 3
# Epoch 30/100
# Average loss :  0.001730663818307221
#
#
# Stage 3
# Epoch 31/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 32/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 33/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 34/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 35/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 36/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 37/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 38/100
# Average loss :  0.0017350228736177087
#
#
# Stage 3
# Epoch 39/100
# Average loss :  0.001730685238726437
#
#
# Stage 3
# Epoch 40/100
# Average loss :  0.0017361348727717996
#
#
# Stage 3
# Epoch 41/100
# Average loss :  0.001740280189551413
#
#
# Stage 3
# Epoch 42/100
# Average loss :  0.0017315908335149288
#
#
# Stage 3
# Epoch 43/100
# Average loss :  0.0017363205552101135
#
#
# Stage 3
# Epoch 44/100
# Average loss :  0.001730663818307221
#
#
# Stage 3
# Epoch 45/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 46/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 47/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 48/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 49/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 50/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 51/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 52/100
# Average loss :  0.0017350228736177087
#
#
# Stage 3
# Epoch 53/100
# Average loss :  0.001730685238726437
#
#
# Stage 3
# Epoch 54/100
# Average loss :  0.0017361348727717996
#
#
# Stage 3
# Epoch 55/100
# Average loss :  0.001740280189551413
#
#
# Stage 3
# Epoch 56/100
# Average loss :  0.0017315908335149288
#
#
# Stage 3
# Epoch 57/100
# Average loss :  0.0017363205552101135
#
#
# Stage 3
# Epoch 58/100
# Average loss :  0.001730663818307221
#
#
# Stage 3
# Epoch 59/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 60/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 61/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 62/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 63/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 64/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 65/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 66/100
# Average loss :  0.0017350228736177087
#
#
# Stage 3
# Epoch 67/100
# Average loss :  0.001730685238726437
#
#
# Stage 3
# Epoch 68/100
# Average loss :  0.0017361348727717996
#
#
# Stage 3
# Epoch 69/100
# Average loss :  0.001740280189551413
#
#
# Stage 3
# Epoch 70/100
# Average loss :  0.0017315908335149288
#
#
# Stage 3
# Epoch 71/100
# Average loss :  0.0017363205552101135
#
#
# Stage 3
# Epoch 72/100
# Average loss :  0.001730663818307221
#
#
# Stage 3
# Epoch 73/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 74/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 75/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 76/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 77/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 78/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 79/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 80/100
# Average loss :  0.0017350228736177087
#
#
# Stage 3
# Epoch 81/100
# Average loss :  0.001730685238726437
#
#
# Stage 3
# Epoch 82/100
# Average loss :  0.0017361348727717996
#
#
# Stage 3
# Epoch 83/100
# Average loss :  0.001740280189551413
#
#
# Stage 3
# Epoch 84/100
# Average loss :  0.0017315908335149288
#
#
# Stage 3
# Epoch 85/100
# Average loss :  0.0017363205552101135
#
#
# Stage 3
# Epoch 86/100
# Average loss :  0.001730663818307221
#
#
# Stage 3
# Epoch 87/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 88/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 89/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 90/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 91/100
# Average loss :  0.0017377235926687717
#
#
# Stage 3
# Epoch 92/100
# Average loss :  0.0017327889800071716
#
#
# Stage 3
# Epoch 93/100
# Average loss :  0.0017385692335665226
#
#
# Stage 3
# Epoch 94/100
# Average loss :  0.0017350228736177087
#
#
# Stage 3
# Epoch 95/100
# Average loss :  0.001730685238726437
#
#
# Stage 3
# Epoch 96/100
# Average loss :  0.0017361348727717996
#
#
# Stage 3
# Epoch 97/100
# Average loss :  0.001740280189551413
#
#
# Stage 3
# Epoch 98/100
# Average loss :  0.0017315908335149288
#
#
# Stage 3
# Epoch 99/100
# Average loss :  0.0017363205552101135
#
#
# Stage 3
# Epoch 100/100
# Average loss :  0.001730663818307221
#
#
# Stage 4
# Epoch 0/100
# Average loss :  0.0015356217045336962
#
#
# Stage 4
# Epoch 1/100
# Average loss :  0.0009568374953232706

# %%
# Out:
# Result stage 4: 1.0*x1_t**2*sin(x0)**2 + 19.56*cos(x0)

# %%
## Adding known terms
L = str(simplify(L)) + " + " + known_expr[0]
print("\m")
print("Obtained Lagrangian: ", L)

expr = expr + known_expr
xi_L = torch.cat((xi_L, c))
mask = torch.ones(len(xi_L),device=device)

# %%
if(save==True):
    #Saving Equation in string
    text_file = open(rootdir + "lagrangian_" + str(noiselevel)+ "_noise.txt", "w")
    text_file.write(L)
    text_file.close()
